# %% [markdown]
# [View in Colaboratory](https://colab.research.google.com/github/nisar009/Kaggle_Notebooks/blob/master/kg2.ipynb)

# %%
# %%capture
# !pip install fastai
# !pip install torch torchvision
# !pip install kaggle-cli

# %%
# !mkdir -p data/homecredit && cd data/homecredit && kg download -u nisar009 -p p@55w0rd -c home-credit-default-risk

# %%
# !cd data/homecredit && for i in `ls`; do unzip $i; done

# %%
# !cd data/homecredit && ls

# %%
import pandas as pd

PATH = 'data/homecredit/'

df = pd.read_csv(f'{PATH}application_train.csv')
df.head()

# %%
from fastai.imports import *
DataFrameSummary(df).summary()

# %%
df_bureau = pd.read_csv(f'{PATH}bureau.csv')
DataFrameSummary(df_bureau).summary()

# %% [markdown]
# Downloading data from the featuretools kernel

# %%
# !mkdir -p data/homecredit/featuretools && cd data/homecredit/featuretools && wget --header="Host: storage.googleapis.com" --header="User-Agent: Mozilla/5.0 (Windows NT 6.1; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/67.0.3396.87 Safari/537.36" --header="Accept: text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,image/apng,*/*;q=0.8" --header="Accept-Language: en-US,en;q=0.9" "https://storage.googleapis.com/kaggle-datasets/28921/40754/feature_matrix.csv.zip?GoogleAccessId=web-data@kaggle-161607.iam.gserviceaccount.com&Expires=1529337819&Signature=cFbPqR4K4CHq%2B4WVTylsDZ9Q4yMa6h5Y%2FboNjLOWHfhkfV7duH7GEd10fhQ7s%2BNbKk%2BcHe6kYIhtu2o0WInwzHQtE4uqZNkcFEtZhar%2BHMlXHJ%2B5ZoVOXoHr%2FhcYHdXs71z3kvCqO6l3TxYWbvIMFmX82cyxwDpFqLA7Mr%2FuNaYGa%2F6%2BGot1%2B3NyY%2BDd7sKqpc3I6MxUZ8KdTRcnQLpLsTl1HpqsRtu7cS3r7URXjout8vFybQemO%2FFtmX%2Fx5XLJLBqkswvqXVnpeDtddx8oBnsEK8jaWcH6oHbCk5hCSgJaBzbwgYuKmRT55gvF%2FksmcD8ty18JlhTc24yx2W1PDw%3D%3D" -O "feature_matrix.csv.zip" -c
# Out:
# --2018-06-18 15:19:06--  https://storage.googleapis.com/kaggle-datasets/28921/40754/feature_matrix.csv.zip?GoogleAccessId=web-data@kaggle-161607.iam.gserviceaccount.com&Expires=1529337819&Signature=cFbPqR4K4CHq%2B4WVTylsDZ9Q4yMa6h5Y%2FboNjLOWHfhkfV7duH7GEd10fhQ7s%2BNbKk%2BcHe6kYIhtu2o0WInwzHQtE4uqZNkcFEtZhar%2BHMlXHJ%2B5ZoVOXoHr%2FhcYHdXs71z3kvCqO6l3TxYWbvIMFmX82cyxwDpFqLA7Mr%2FuNaYGa%2F6%2BGot1%2B3NyY%2BDd7sKqpc3I6MxUZ8KdTRcnQLpLsTl1HpqsRtu7cS3r7URXjout8vFybQemO%2FFtmX%2Fx5XLJLBqkswvqXVnpeDtddx8oBnsEK8jaWcH6oHbCk5hCSgJaBzbwgYuKmRT55gvF%2FksmcD8ty18JlhTc24yx2W1PDw%3D%3D
# Resolving storage.googleapis.com (storage.googleapis.com)... 74.125.201.128, 2607:f8b0:4001:c14::80
# Connecting to storage.googleapis.com (storage.googleapis.com)|74.125.201.128|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 990885600 (945M) [application/zip]
# Saving to: ‘feature_matrix.csv.zip’
#
# feature_matrix.csv. 100%[===================>] 944.98M   150MB/s    in 7.0s
#
# ...

# %%
# !cd data/homecredit/featuretools && wget --header="Host: storage.googleapis.com" --header="User-Agent: Mozilla/5.0 (Windows NT 6.1; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/67.0.3396.87 Safari/537.36" --header="Accept: text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,image/apng,*/*;q=0.8" --header="Accept-Language: en-US,en;q=0.9" "https://storage.googleapis.com/kaggle-datasets/28921/40754/feature_importances.csv?GoogleAccessId=web-data@kaggle-161607.iam.gserviceaccount.com&Expires=1529338183&Signature=HncQSjkQxBE%2BrDMJgOmP8oWENPigDv3qN7FOdNT4Ba3G9%2B8xgBnhwunlY0edPbKhpEUnmRQUiy9KtpaIj0s8ZtkIz%2BbalWTeDr72Y%2B0sBWrpsi9xYX97bSPpFRn9eikmvC4yLyV5irSAyhAgCXKWRtx3KYKQro44H3Bshu2MhIXqOX4gFotYkU8OvYOT5L8QSFqdxeC9I%2BS6okQu6qRGko%2F6cw9J7kuLvcYdVaqtv3pAbxPWLL9c%2FQ6AnBwBobBHEAHh7a8C4F%2FUzhtIhziqPzrQe3TVSokeaD2K3dKrlGjZ%2BZ93bhg4fvwT8xHzAbeXDhDyEt1gjGGqvBUZoqoIJw%3D%3D" -O "feature_importances.csv" -c
# Out:
# --2018-06-18 15:19:19--  https://storage.googleapis.com/kaggle-datasets/28921/40754/feature_importances.csv?GoogleAccessId=web-data@kaggle-161607.iam.gserviceaccount.com&Expires=1529338183&Signature=HncQSjkQxBE%2BrDMJgOmP8oWENPigDv3qN7FOdNT4Ba3G9%2B8xgBnhwunlY0edPbKhpEUnmRQUiy9KtpaIj0s8ZtkIz%2BbalWTeDr72Y%2B0sBWrpsi9xYX97bSPpFRn9eikmvC4yLyV5irSAyhAgCXKWRtx3KYKQro44H3Bshu2MhIXqOX4gFotYkU8OvYOT5L8QSFqdxeC9I%2BS6okQu6qRGko%2F6cw9J7kuLvcYdVaqtv3pAbxPWLL9c%2FQ6AnBwBobBHEAHh7a8C4F%2FUzhtIhziqPzrQe3TVSokeaD2K3dKrlGjZ%2BZ93bhg4fvwT8xHzAbeXDhDyEt1gjGGqvBUZoqoIJw%3D%3D
# Resolving storage.googleapis.com (storage.googleapis.com)... 209.85.147.128, 2607:f8b0:4001:c14::80
# Connecting to storage.googleapis.com (storage.googleapis.com)|209.85.147.128|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 85223 (83K) [application/vnd.ms-excel]
# Saving to: ‘feature_importances.csv’
#
# feature_importances 100%[===================>]  83.23K  --.-KB/s    in 0.002s
#
# ...

# %%
# !cd data/homecredit/featuretools && ls && unzip feature_matrix.csv.zip && ls -al
# Out:
# feature_importances.csv  feature_matrix.csv.zip
# Archive:  feature_matrix.csv.zip
#   inflating: feature_matrix.csv
# total 3940488
# drwxr-xr-x 2 root root       4096 Jun 18 15:19 .
# drwxr-xr-x 3 root root       4096 Jun 18 15:19 ..
# -rw-r--r-- 1 root root      85223 Jun 15 00:51 feature_importances.csv
# -rw-r--r-- 1 root root 3044059820 Jun 15 00:54 feature_matrix.csv
# -rw-r--r-- 1 root root  990885600 Jun 15 01:31 feature_matrix.csv.zip

# %%
# !cd data/homecredit/featuretools && ls -lah
# Out:
# total 3.8G
# drwxr-xr-x 2 root root 4.0K Jun 18 15:19 .
# drwxr-xr-x 3 root root 4.0K Jun 18 15:19 ..
# -rw-r--r-- 1 root root  84K Jun 15 00:51 feature_importances.csv
# -rw-r--r-- 1 root root 2.9G Jun 15 00:54 feature_matrix.csv
# -rw-r--r-- 1 root root 945M Jun 15 01:31 feature_matrix.csv.zip

# %%
from fastai.imports import *

PATH = "data/homecredit/featuretools/"

# %%
reader = pd.read_csv(f'{PATH}feature_matrix.csv', chunksize=100000)
df = reader.get_chunk(100000)
df.head()
# Out:
#    SK_ID_CURR NAME_TYPE_SUITE  REG_REGION_NOT_LIVE_REGION  EXT_SOURCE_2  \
# 0      100001   Unaccompanied                           0      0.789654
# 1      100002   Unaccompanied                           0      0.262949
# 2      100003          Family                           0      0.622246
# 3      100004   Unaccompanied                           0      0.555912
# 4      100005   Unaccompanied                           0      0.291656
#
#       OCCUPATION_TYPE  FLAG_PHONE  AMT_INCOME_TOTAL  AMT_CREDIT  \
# 0                 NaN           0          135000.0    568800.0
# 1            Laborers           1          202500.0    406597.5
# 2          Core staff           1          270000.0   1293502.5
# 3            Laborers           1           67500.0    135000.0
# 4  Low-skill Laborers           0           99000.0    222768.0
#
#    REGION_RATING_CLIENT  REG_REGION_NOT_WORK_REGION  \
# 0                     2                           0
# ...

# %%
df_train = df[df['set'] == 'train']
df_test = df[df['set'] == 'test']

# %%
len(df_train)
len(df_test)
# Out:
# 13827

# %%
feature_imp = pd.read_csv(f'{PATH}feature_importances.csv')
feature_imp.head()
# Out:
#    index            feature  importance
# 0     24  ORGANIZATION_TYPE        5504
# 1     74       EXT_SOURCE_1        2304
# 2      2       EXT_SOURCE_2        2298
# 3     42       EXT_SOURCE_3        2298
# 4    105        AMT_ANNUITY        1121

# %%
best_100 = feature_imp['feature'][:100].append(pd.Series(["SK_ID_CURR", "TARGET"]))

# %%
df_train_best_100 = df_train[best_100]
df_test_best_100 = df_test[best_100]

# %%
df_test_best_100.drop('TARGET', axis=1, inplace=True)
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %% [markdown]
# Fastai Start Here

# %%
from fastai.imports import *
from fastai.structured import *
from fastai.column_data import *
from torch.nn import functional as F
from sklearn.metrics import roc_auc_score
from sklearn.model_selection import train_test_split

# %%
df_train_best_100.dtypes.value_counts()
# Out:
# float64    89
# object      7
# int64       6
# dtype: int64

# %%
cat_vars = [col for col in df_train_best_100 if df_train_best_100[col].dtype.name != 'float64' and df_train_best_100[col].dtype.name != 'float32' and 
           len(df_train_best_100[col].unique()) < 150]
cat_vars
# Out:
# ['ORGANIZATION_TYPE',
#  'OCCUPATION_TYPE',
#  'MODE(previous_app.PRODUCT_COMBINATION)',
#  'CODE_GENDER',
#  'NAME_FAMILY_STATUS',
#  'NAME_EDUCATION_TYPE',
#  'MODE(previous_app.NAME_GOODS_CATEGORY)',
#  'REGION_RATING_CLIENT_W_CITY',
#  'TARGET']

# %%
cat_vars.remove('TARGET')
cat_vars
# Out:
# ['ORGANIZATION_TYPE',
#  'OCCUPATION_TYPE',
#  'MODE(previous_app.PRODUCT_COMBINATION)',
#  'CODE_GENDER',
#  'NAME_FAMILY_STATUS',
#  'NAME_EDUCATION_TYPE',
#  'MODE(previous_app.NAME_GOODS_CATEGORY)',
#  'REGION_RATING_CLIENT_W_CITY']

# %%
cat_sz = [(c, len(df_train_best_100[c].unique())+1) for c in cat_vars]
cat_sz
# Out:
# [('ORGANIZATION_TYPE', 59),
#  ('OCCUPATION_TYPE', 20),
#  ('MODE(previous_app.PRODUCT_COMBINATION)', 19),
#  ('CODE_GENDER', 4),
#  ('NAME_FAMILY_STATUS', 7),
#  ('NAME_EDUCATION_TYPE', 6),
#  ('MODE(previous_app.NAME_GOODS_CATEGORY)', 28),
#  ('REGION_RATING_CLIENT_W_CITY', 4)]

# %%
# Train and validation split
y = np.array(df_train_best_100['TARGET'])
df_train_best_100.drop('TARGET', axis=1, inplace=True)
df_to_nn_train, df_to_nn_valid, y_train, y_valid = train_test_split(df_train_best_100, y, test_size=0.33, random_state=23, stratify=y)
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
DataFrameSummary(df_to_nn_train).summary()
# Out:
#              ORGANIZATION_TYPE EXT_SOURCE_1 EXT_SOURCE_2 EXT_SOURCE_3  \
# count                      NaN        25248        57605        46336
# mean                       NaN      0.50382     0.514524     0.510842
# std                        NaN     0.210919     0.191624     0.194985
# min                        NaN    0.0183608  8.17362e-08  0.000527265
# 25%                        NaN     0.336069      0.39179      0.37065
# 50%                        NaN     0.509633     0.566477     0.535276
# 75%                        NaN     0.676257     0.664266     0.669057
# max                        NaN     0.951624        0.855      0.89601
# counts                   57735        25248        57605        46336
# uniques                     58        24474        43962          739
# missing                      0        32487          130        11399
# missing_perc                0%       56.27%        0.23%       19.74%
# ...

# %%
def preprocess_fast_ai(df_to_nn_train, df_to_nn_valid, cat_vars):
  # Declare categorical variables
  for v in cat_vars:
    df_to_nn_train[v] = df_to_nn_train[v].astype('category').cat.as_ordered()
  apply_cats(df_to_nn_valid, df_to_nn_train)
  
  # Deal with missingness and put everything as number
  df, _, nas, mapper = proc_df(df_to_nn_train, do_scale=True, skip_flds=['SK_ID_CURR'])
  df_valid, _, nas, mapper = proc_df(df_to_nn_valid, do_scale=True, na_dict=nas, mapper=mapper, skip_flds=['SK_ID_CURR'])
  
  return df, df_valid

# %%
df, df_valid = preprocess_fast_ai(df_to_nn_train, df_to_nn_valid, cat_vars)
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.
# /usr/local/lib/python3.6/dist-packages/fastai/structured.py:200: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   df[n] = pd.Categorical(c, categories=trn[n].cat.categories, ordered=True)
# /usr/local/lib/python3.6/dist-packages/fastai/structured.py:425: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...

# %%
DataFrameSummary(df).summary()
# Out:
#              ORGANIZATION_TYPE EXT_SOURCE_1 EXT_SOURCE_2 EXT_SOURCE_3  \
# count                    57735        57735        57735        57735
# mean                    30.444  7.84877e-16 -1.90758e-16  4.88587e-16
# std                    20.4382      1.00001      1.00001      1.00001
# min                          1     -3.50329     -2.68851     -2.94454
# 25%                          6    0.0182225    -0.638704    -0.563407
# 50%                         34    0.0182225     0.270791     0.112091
# 75%                         48    0.0182225     0.780728     0.689979
# max                         58      3.18647      1.77805      2.17404
# counts                   57735        57735        57735        57735
# uniques                     58        24475        43962          739
# missing                      0            0            0            0
# missing_perc                0%           0%           0%           0%
# ...

# %%
emb_szs = [(c, min(50, (c+1)//2)) for _, c in cat_sz]
emb_szs
# Out:
# [(59, 30), (20, 10), (19, 10), (4, 2), (7, 4), (6, 3), (28, 14), (4, 2)]

# %%
# Define the data loader

md = ColumnarModelData.from_data_frames(PATH, trn_df=df, val_df=df_valid, trn_y=y_train.astype('int'), val_y=y_valid.astype('int'), cat_flds=cat_vars, bs=512, is_reg=False, is_multi=False)

# %%
class MixedInputModel(nn.Module):
    def __init__(self, emb_szs, n_cont, emb_drop, out_sz, szs, drops,
                 y_range=None, use_bn=False, is_reg=True, is_multi=False):
        super().__init__()
        self.embs = nn.ModuleList([nn.Embedding(c, s) for c,s in emb_szs])
        for emb in self.embs: emb_init(emb)
        n_emb = sum(e.embedding_dim for e in self.embs)
        self.n_emb, self.n_cont= n_emb, n_cont
        szs = [n_emb + n_cont] + szs
        self.lins = nn.ModuleList([
            nn.Linear(szs[i], szs[i+1]) for i in range(len(szs)-1)])
        self.bns = nn.ModuleList([
            nn.BatchNorm1d(sz) for sz in szs[1:]])
        for o in self.lins: kaiming_normal(o.weight.data)
        self.outp = nn.Linear(szs[-1], out_sz)
        kaiming_normal(self.outp.weight.data)
        
        self.emb_drop = nn.Dropout(emb_drop)
        self.drops = nn.ModuleList([nn.Dropout(drop) for drop in drops])
        self.bn = nn.BatchNorm1d(n_cont)
        self.use_bn,self.y_range = use_bn,y_range
        self.is_reg = is_reg
        self.is_multi = is_multi

    def forward(self, x_cat, x_cont):
        x = []
        for i,e in enumerate(self.embs):
            x.append(e(x_cat[:,i]))
        x = torch.cat(x, 1)
        x = self.emb_drop(x)
        x2 = self.bn(x_cont)
        x = torch.cat([x, x2], 1)
        for l,d,b in zip(self.lins, self.drops, self.bns):
            x = F.relu(l(x))
            if self.use_bn: x = b(x)
            x = d(x)
        x = self.outp(x)
        x = F.log_softmax(x)
        return x

# %%
# Define Model
m = MixedInputModel(emb_szs, n_cont = len(df.columns)-len(cat_vars),
                   emb_drop = 0.05, out_sz = 2, szs = [500, 250, 250], drops = [0.1, 0.1, 0.1], 
                   y_range = None, use_bn = False, is_reg = False, is_multi = False)
bm = BasicModel(m.cuda(), 'binary_classifier')
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-103-c4fa8571cbd7> in <module>()
#       2                    emb_drop = 0.05, out_sz = 2, szs = [500, 250, 250], drops = [0.1, 0.1, 0.1],
#       3                    y_range = None, use_bn = False, is_reg = False, is_multi = False)
# ----> 4 bm = BasicModel(m.cuda(), 'binary_classifier')
#
# /usr/local/lib/python3.6/dist-packages/torch/nn/modules/module.py in cuda(self, device)
#     214             Module: self
#     215         """
# --> 216         return self._apply(lambda t: t.cuda(device))
#     217
#     218     def cpu(self):
#
# /usr/local/lib/python3.6/dist-packages/torch/nn/modules/module.py in _apply(self, fn)
#     144     def _apply(self, fn):
#     145         for module in self.children():
# --> 146             module._apply(fn)
#     147
#     148         for param in self._parameters.values():
#
# ...

# %%
# Define Learner
class StructuredLearner(Learner):
    def __init__(self, data, models, **kwargs):
        super().__init__(data, models, **kwargs)
        self.crit = F.nll_loss
# Instantiate learner
learn = StructuredLearner(md, bm)

# %%
learn.lr_find(1e-4, 1)
learn.sched.plot()

# %%
df.columns
# Out:
# Index(['ORGANIZATION_TYPE', 'EXT_SOURCE_1', 'EXT_SOURCE_2', 'EXT_SOURCE_3',
#        'AMT_ANNUITY', 'DAYS_BIRTH', 'AMT_CREDIT', 'MAX(bureau.DAYS_CREDIT)',
#        'DAYS_ID_PUBLISH', 'DAYS_EMPLOYED',
#        ...
#        'MIN(previous_app.MEAN(installments.AMT_PAYMENT))_na',
#        'MEAN(previous_app.DAYS_DECISION)_na',
#        'STD(previous_app.RATE_DOWN_PAYMENT)_na',
#        'MIN(previous_app.SKEW(installments.AMT_PAYMENT))_na',
#        'SUM(previous_app.SELLERPLACE_AREA)_na',
#        'MEAN(previous_app.AMT_ANNUITY)_na', 'YEARS_BEGINEXPLUATATION_MEDI_na',
#        'MEAN(previous_app.SKEW(installments.AMT_PAYMENT))_na',
#        'DEF_30_CNT_SOCIAL_CIRCLE_na',
#        'MIN(previous_app.MAX(installments.AMT_INSTALMENT))_na'],
#       dtype='object', length=184)

# %%
df_valid.describe()
# Out:
#        ORGANIZATION_TYPE  EXT_SOURCE_1  EXT_SOURCE_2  EXT_SOURCE_3  \
# count       28438.000000  28438.000000  28438.000000  28438.000000
# mean           30.301498     -0.004511     -0.006588     -0.001988
# std            20.414290      0.998516      0.998908      1.000342
# min             1.000000     -3.530474     -2.688450     -2.944537
# 25%             6.000000      0.018222     -0.643264     -0.580928
# 50%            34.000000      0.018222      0.268631      0.112091
# 75%            47.000000      0.018222      0.777299      0.689979
# max            58.000000      3.134830      1.778047      2.113905
#
#         AMT_ANNUITY    DAYS_BIRTH    AMT_CREDIT  MAX(bureau.DAYS_CREDIT)  \
# count  28438.000000  28438.000000  28438.000000             28438.000000
# mean       0.004308      0.009393      0.000924                -0.010764
# std        1.025674      1.001963      1.000403                 1.005691
# ...

# %%
learner = md.get_learner(emb_szs, len(df.columns)-len(cat_vars), 0.04, 1, [1000, 500], [0.001, 0.01])

# %%
learner.lr_find()
# Out:
# ...
#   0%|          | 0/113 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-93-f01cf5c6afa7> in <module>()
# ----> 1 learner.lr_find()
#
# /usr/local/lib/python3.6/dist-packages/fastai/learner.py in lr_find(self, start_lr, end_lr, wds, linear, **kwargs)
#     328         layer_opt = self.get_layer_opt(start_lr, wds)
#     329         self.sched = LR_Finder(layer_opt, len(self.data.trn_dl), end_lr, linear=linear)
# --> 330         self.fit_gen(self.model, self.data, layer_opt, 1, **kwargs)
#     331         self.load('tmp')
#     332
#
# /usr/local/lib/python3.6/dist-packages/fastai/learner.py in fit_gen(self, model, data, layer_opt, n_cycle, cycle_len, cycle_mult, cycle_save_name, best_save_name, use_clr, use_clr_beta, metrics, callbacks, use_wd_sched, norm_wds, wds_sched_mult, use_swa, swa_start, swa_eval_freq, **kwargs)
# ...
