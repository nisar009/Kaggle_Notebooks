# %%
import utils

# %%
# %load_ext autoreload
# %autoreload 2

# %%
filename = '14de0ff6-bbca-11e8-b2bc-ac1f6b6435d0'

# %%
from pathlib import Path

# %%
path = Path('.')/'data'/'protein'/'train_images'

# %%
# %%timeit
img = utils.open_4_channel(str(path/filename))
# Out:
# 12 ms ± 132 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)

# %%
img = utils.open_4_channel(str(path/filename))

# %%
import matplotlib.pyplot as plt

# %%
img
# Out:
# Image (4, 512, 512)
